# %% [markdown]
# <a href="https://colab.research.google.com/github/misrori/scraping_2024/blob/main/session_3_vienna_airport.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install scrapethat
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.7/99.7 kB 3.5 MB/s eta 0:00:00
# ...

# %%
from scrapethat import *

# %%
t = fromjson('https://www.viennaairport.com/jart/prj3/va/data/flights/inc.json')

# %%
df = pd.json_normalize(t['monitor']['departure'])

# %%
df
# Out:
#      idx        fn      scheduledatetime                 schedule  \
# 0      0   UPS 274  2024-11-19T04:10:00Z  2024-11-19T05:10:00.000
# 1      1   FX 4486  2024-11-19T04:50:00Z  2024-11-19T05:50:00.000
# 2      2    ET 730  2024-11-19T04:55:00Z  2024-11-19T05:55:00.000
# 3      3    NH 205  2024-11-19T05:00:00Z  2024-11-19T06:00:00.000
# 4      4  ABR 4819  2024-11-19T05:05:00Z  2024-11-19T06:05:00.000
# ..   ...       ...                   ...                      ...
# 354  354    EK 127  2024-11-20T11:25:00Z  2024-11-20T12:25:00.000
# 355  355    OS 226  2024-11-20T11:35:00Z  2024-11-20T12:35:00.000
# 356  356    VF 017  2024-11-20T11:55:00Z  2024-11-20T12:55:00.000
# 357  357   VY 4212  2024-11-20T11:55:00Z  2024-11-20T12:55:00.000
# 358  358   SM 2990  2024-11-20T12:00:00Z  2024-11-20T13:00:00.000
#
#            actualdatetime                   actual  \
# 0    2024-11-19T04:30:00Z  2024-11-19T05:30:00.000
# 1    2024-11-19T05:07:00Z  2024-11-19T06:07:00.000
# ...

# %%
df.dtypes
# Out:
# idx                      int64
# fn                      object
# scheduledatetime        object
# schedule                object
# actualdatetime          object
# actual                  object
# codeshares              object
# origins                 object
# status.code             object
# status.description      object
# belt.belt               object
# aircraft.type           object
# aircraft.description    object
# airline.name            object
# airline.webSite         object
# airline.iataCode        object
# airline.icaoCode        object
# dtype: object

# %%
import requests
t = fromjson('http://numbersapi.com/5/math?json')

# %%
t
# Out:
# {'text': '5 is the third prime number.',
#  'number': 5,
#  'found': True,
#  'type': 'math'}
